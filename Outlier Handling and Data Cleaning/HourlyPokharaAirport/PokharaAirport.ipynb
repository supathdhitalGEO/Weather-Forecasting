# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("./HourlyDataset.csv")
df.shape
# Out:
# (26209, 5)

# %%
#Total Null data available in the Dataset
df.isnull().sum()
# Out:
# Time                                             0
# Accumulated Precipitation for last 1 h(Avg)    600
# Air Temperature 1 Hour Average(Avg)            285
# Relative Humidity 1 hour average(Avg)          284
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         286
# dtype: int64

# %%
#changing the string type of time to the date data type
df['Time']=pd.to_datetime(df['Time'])
#changing the format of the date
df['Time']= df["Time"].dt.strftime('%Y-%m-%d %H:%M:%S')
df[:10]
# Out:
#                   Time  Accumulated Precipitation for last 1 h(Avg)  \
# 0  2019-11-11 06:00:00                                          0.0
# 1  2019-11-11 07:00:00                                          0.0
# 2  2019-11-11 08:00:00                                          0.0
# 3  2019-11-11 09:00:00                                          0.0
# 4  2019-11-11 10:00:00                                          0.0
# 5  2019-11-11 11:00:00                                          0.0
# 6  2019-11-11 12:00:00                                          0.0
# 7  2019-11-11 13:00:00                                          0.0
# 8  2019-11-11 14:00:00                                          0.0
# 9  2019-11-11 15:00:00                                          0.0
#
#    Air Temperature 1 Hour Average(Avg)  Relative Humidity 1 hour average(Avg)  \
# 0                               23.400                                 69.399
# ...

# %%
# # data_range = pd.date_range(start="2019-11-11 06:00:00", end="2011-11-07 06:00:00", freq="1H")
# # df.reindex(data_range, fill_value= ' ')
# df.drop('Unnamed: 0', inplace=True, axis=1)
# df.columns

# %%
df
# Out:
#                       Time  Accumulated Precipitation for last 1 h(Avg)  \
# 0      2019-11-11 06:00:00                                          0.0
# 1      2019-11-11 07:00:00                                          0.0
# 2      2019-11-11 08:00:00                                          0.0
# 3      2019-11-11 09:00:00                                          0.0
# 4      2019-11-11 10:00:00                                          0.0
# ...                    ...                                          ...
# 26204  2022-07-11 02:00:00                                          0.0
# 26205  2022-07-11 03:00:00                                          0.0
# 26206  2022-07-11 04:00:00                                          0.0
# 26207  2022-07-11 05:00:00                                          0.0
# 26208  2022-07-11 06:00:00                                          0.0
#
#        Air Temperature 1 Hour Average(Avg)  \
# 0                                     23.4
# ...

# %%
# #Importing the missing hours in the DataFrame
df['Time'] = pd.to_datetime(df['Time'],format='%Y-%m-%d %H:%M:%S')
df = df.set_index(['Time']).resample('1H').last().reset_index()
df

# %%
df.isnull().sum()
# Out:
# Time                                             0
# Accumulated Precipitation for last 1 h(Avg)    600
# Air Temperature 1 Hour Average(Avg)            285
# Relative Humidity 1 hour average(Avg)          284
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         286
# dtype: int64

# %%
#downloading the new Dataset:
# df.to_csv("UpdatedDataframe.csv")

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# Time                                             0
# Accumulated Precipitation for last 1 h(Avg)    600
# Air Temperature 1 Hour Average(Avg)            285
# Relative Humidity 1 hour average(Avg)          284
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         286
# dtype: int64

# %%
len(df)
#percentage missing data
Percentage= (missing_data/len(df))*100
Percentage
#by this we got the missing percentage of 4.85%
# Out:
# Time                                           0.000000
# Accumulated Precipitation for last 1 h(Avg)    2.289290
# Air Temperature 1 Hour Average(Avg)            1.087413
# Relative Humidity 1 hour average(Avg)          1.083597
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         1.091228
# dtype: float64

# %%
#set date as index:
df.set_index('Time', inplace=True)

# %%
df[1386:1396]
# Out:
#                      Accumulated Precipitation for last 1 h(Avg)  \
# Time
# 2020-08-01 00:00:00                                          NaN
# 2020-08-01 01:00:00                                          NaN
# 2020-08-01 02:00:00                                          0.0
# 2020-08-01 03:00:00                                          NaN
# 2020-08-01 04:00:00                                          NaN
# 2020-08-01 05:00:00                                          0.0
# 2020-08-01 06:00:00                                          NaN
# 2020-08-01 07:00:00                                          NaN
# 2020-08-01 08:00:00                                          0.0
# 2020-08-01 09:00:00                                          NaN
#
#                      Air Temperature 1 Hour Average(Avg)  \
# Time
# 2020-08-01 00:00:00                                  NaN
# 2020-08-01 01:00:00                                  9.2
# 2020-08-01 02:00:00                                  8.7
# ...

# %%
#applying interpolation into the dataframe
df1=df.interpolate(method='linear')

# %%
#Checking the dataframe whether it is applied or not
df1[1386:1396]
# Out:
#                      Accumulated Precipitation for last 1 h(Avg)  \
# Time
# 2020-08-01 00:00:00                                     0.000000
# 2020-08-01 01:00:00                                     0.000000
# 2020-08-01 02:00:00                                     0.000000
# 2020-08-01 03:00:00                                     0.000000
# 2020-08-01 04:00:00                                     0.000000
# 2020-08-01 05:00:00                                     0.000000
# 2020-08-01 06:00:00                                     0.000000
# 2020-08-01 07:00:00                                     0.000000
# 2020-08-01 08:00:00                                     0.000000
# 2020-08-01 09:00:00                                     0.066667
#
#                      Air Temperature 1 Hour Average(Avg)  \
# Time
# 2020-08-01 00:00:00                             9.233333
# 2020-08-01 01:00:00                             9.200000
# 2020-08-01 02:00:00                             8.700000
# ...

# %%
df1.isnull().sum()
# Out:
# Accumulated Precipitation for last 1 h(Avg)    0
# Air Temperature 1 Hour Average(Avg)            0
# Relative Humidity 1 hour average(Avg)          0
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         0
# dtype: int64

# %%
# df1.to_csv('CleanedHourlyData.csv')

# %%
df1.describe()
# Out:
#        Accumulated Precipitation for last 1 h(Avg)  \
# count                                 26209.000000
# mean                                      0.556503
# std                                       3.148025
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                      76.000000
#
#        Air Temperature 1 Hour Average(Avg)  \
# count                         26209.000000
# mean                             20.270232
# std                               6.309492
# min                               3.500000
# 25%                              15.600000
# 50%                              21.600000
# 75%                              24.500000
# max                              37.200000
#
#        Relative Humidity 1 hour average(Avg)  \
# count                           26209.000000
# ...

# %%
dataset=pd.read_csv('./CleanedHourlyData.csv')
dataset
# Out:
#                    Time  Accumulated Precipitation for last 1 h(Avg)  \
# 0       11/11/2019 6:00                                          0.0
# 1       11/11/2019 7:00                                          0.0
# 2       11/11/2019 8:00                                          0.0
# 3       11/11/2019 9:00                                          0.0
# 4      11/11/2019 10:00                                          0.0
# ...                 ...                                          ...
# 26204   11/07/2022 2:00                                          0.0
# 26205   11/07/2022 3:00                                          0.0
# 26206   11/07/2022 4:00                                          0.0
# 26207   11/07/2022 5:00                                          0.0
# 26208   11/07/2022 6:00                                          0.0
#
#        Air Temperature 1 Hour Average(Avg)  \
# 0                                     23.4
# 1                                     24.3
# ...

# %%
dataset.isnull().sum()
# Out:
# Time                                           0
# Accumulated Precipitation for last 1 h(Avg)    0
# Air Temperature 1 Hour Average(Avg)            0
# Relative Humidity 1 hour average(Avg)          0
# Wind speed (m/s) at 10 m, 1 h avg(Avg)         0
# dtype: int64

# %%
dataset['Time']=pd.to_datetime(dataset['Time'])
index=dataset.set_index('Time')

# %%
weekly=index['2019-11-11':'2022-07-11'].resample('W').sum()
# weekly.to_csv('./hi.csv')
weekly
# Out:
#             Accumulated Precipitation for last 1 h(Avg)  \
# Time
# 2019-11-17                                          0.0
# 2019-11-24                                          0.0
# 2019-12-01                                          0.2
# 2019-12-08                                          0.2
# 2019-12-15                                         36.3
# ...                                                 ...
# 2022-06-19                                        137.0
# 2022-06-26                                        214.8
# 2022-07-03                                        264.2
# 2022-07-10                                        182.8
# 2022-07-17                                          1.2
#
#             Air Temperature 1 Hour Average(Avg)  \
# Time
# 2019-11-17                              3218.53
# 2019-11-24                              2985.40
# 2019-12-01                              2775.40
# 2019-12-08                              2410.90
# ...
